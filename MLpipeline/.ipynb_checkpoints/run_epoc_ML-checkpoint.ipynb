# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, "../")

# %%
! python runMLpipelines_Marija.py classification_template_2
# Out:
# /home/marijatochadse/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:31: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# ...
# time:  2023-08-11 15:55:28.613146
# Running MLpipeline on file
#  ("/home/marijatochadse/2_scripts/testfile_noconfs.h5")
#  with 28 different combinations:
#  ( #) confound_control-confs   input-output                        ML model             out_cv_trial
#  ( 0) baseline:                ('X', 'Response')                   LR(c)                      cv_i=0
#  ( 1) baseline:                ('X', 'Response')                   LR(c)                      cv_i=1
#  ( 2) baseline:                ('X', 'Response')                   LR(c)                      cv_i=2
#  ( 3) baseline:                ('X', 'Response')                   LR(c)                      cv_i=3
# ...
