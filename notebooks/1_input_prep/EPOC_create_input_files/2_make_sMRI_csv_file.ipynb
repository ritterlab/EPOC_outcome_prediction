# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pyreadstat
import seaborn as sns
from scipy import stats

cmap = plt.cm.rainbow
import h5py

# %% [markdown]
# #### Select only subjects with demografic info

# %%
# select only subjects with demografic info
epoc_dem = pd.read_csv('/home/marijatochadse/1_data/EPOC/EPOC_T1_pat.csv', sep=",")
pat_labels_epoc = epoc_dem['Code'].unique()
pat_labels_epoc.sort()
print(pat_labels_epoc.shape)
pat_labels_epoc = np.ndarray.tolist(pat_labels_epoc)
print(pat_labels_epoc)
# Out:
# (90,)
# ['epoc_p_1004', 'epoc_p_1005', 'epoc_p_1006', 'epoc_p_1008', 'epoc_p_1012', 'epoc_p_1013', 'epoc_p_1014', 'epoc_p_1015', 'epoc_p_1016', 'epoc_p_1017', 'epoc_p_1018', 'epoc_p_1019', 'epoc_p_1021', 'epoc_p_1022', 'epoc_p_1023', 'epoc_p_1024', 'epoc_p_1025', 'epoc_p_1027', 'epoc_p_1028', 'epoc_p_1029', 'epoc_p_1030', 'epoc_p_1031', 'epoc_p_1033', 'epoc_p_1034', 'epoc_p_1035', 'epoc_p_1036', 'epoc_p_1037', 'epoc_p_1039', 'epoc_p_1040', 'epoc_p_1042', 'epoc_p_1043', 'epoc_p_1044', 'epoc_p_1045', 'epoc_p_1046', 'epoc_p_1047', 'epoc_p_1048', 'epoc_p_1049', 'epoc_p_1050', 'epoc_p_1051', 'epoc_p_1052', 'epoc_p_1053', 'epoc_p_1054', 'epoc_p_1056', 'epoc_p_1057', 'epoc_p_1059', 'epoc_p_1061', 'epoc_p_1062', 'epoc_p_1063', 'epoc_p_1064', 'epoc_p_1065', 'epoc_p_1067', 'epoc_p_1069', 'epoc_p_1071', 'epoc_p_1072', 'epoc_p_1073', 'epoc_p_1074', 'epoc_p_1079', 'epoc_p_1080', 'epoc_p_1081', 'epoc_p_1085', 'epoc_p_1086', 'epoc_p_1087', 'epoc_p_1089', 'epoc_p_1091', 'epoc_p_1093', 'epoc_p_1094', 'epoc_p_1097', 'epoc_p_1099', 'epoc_p_1100', 'epoc_p_1103', 'epoc_p_1108', 'epoc_p_1109', 'epoc_p_1110', 'epoc_p_1114', 'epoc_p_1116', 'epoc_p_1118', 'epoc_p_1119', 'epoc_p_1120', 'epoc_p_1123', 'epoc_p_1124', 'epoc_p_1126', 'epoc_p_1129', 'epoc_p_1130', 'epoc_p_1131', 'epoc_p_1132', 'epoc_p_1136', 'epoc_p_1137', 'epoc_p_1139', 'epoc_p_1140', 'epoc_p_1141']

# %%
def create_MRI_csv(file_path, pat_labels_epoc):
    
    df = pd.read_csv(file_path, sep="\t")
    
    df.iloc[:,0] = df.iloc[:,0].str[4:8] + '_' + df.iloc[:,0].str[8] + '_' + df.iloc[:,0].str[9:13]
    
    df_dem_pat = df.loc[df.iloc[:,0].isin(pat_labels_epoc)]
    print(df_dem_pat.shape)
    
    return df_dem_pat

# %% [markdown]
# #### Make dataframes for freesurfer outputs

# %%
file_path = "/home/marijatochadse/3_output/EPOC/aseg_stats.txt"
df_aseg = create_MRI_csv(file_path, pat_labels_epoc)
df_aseg.head()
# Out:
# (90, 67)
#     Measure:volume  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 111    epoc_p_1004                  5686.7              288.9
# 112    epoc_p_1005                  4581.4              157.1
# 113    epoc_p_1006                  7058.9              231.8
# 114    epoc_p_1008                  9492.9              160.9
# 116    epoc_p_1012                 10666.4              787.6
#
#      Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  \
# 111                       12690.1                 58991.6
# 112                       14484.8                 53596.0
# 113                       14910.9                 55451.5
# 114                       31255.6                 43988.5
# 116                       18939.8                 73133.4
#
#      Left-Thalamus-Proper  Left-Caudate  Left-Putamen  Left-Pallidum  \
# 111                8284.0        3207.3        4425.4         1786.4
# 112                7802.4        3101.7        4596.6         1763.1
# 113                7464.9        3459.2        4485.9         1884.8
# 114                7728.0        3375.6        5109.4         2127.1
# 116                9412.4        3716.4        4606.5         2446.6
#
#      3rd-Ventricle  ...  SupraTentorialVol  SupraTentorialVolNotVent  \
# 111          972.2  ...       1.008349e+06              9.953135e+05
# 112          718.5  ...       9.957580e+05              9.868920e+05
# 113         1085.3  ...       8.807984e+05              8.649774e+05
# 114         1034.3  ...       9.992590e+05              9.825350e+05
# 116         1805.0  ...       1.201988e+06              1.177135e+06
#
#      SupraTentorialVolNotVentVox    MaskVol  BrainSegVol-to-eTIV  \
# 111                     994175.0  1459881.0             0.737189
# 112                     985491.0  1403433.0             0.847117
# 113                     862749.0  1309709.0             0.887720
# 114                     979492.0  1434536.0             0.789093
# 116                    1174192.0  1782012.0             0.748874
#
#      MaskVol-to-eTIV  lhSurfaceHoles  rhSurfaceHoles  SurfaceHoles  \
# 111         0.933129            12.0            22.0          34.0
# 112         1.052022            10.0            21.0          31.0
# 113         1.136375            33.0            34.0          67.0
# 114         0.983211            17.0            13.0          30.0
# 116         0.959570            10.0            20.0          30.0
#
#      EstimatedTotalIntraCranialVol
# 111                   1.564502e+06
# 112                   1.334034e+06
# 113                   1.152532e+06
# 114                   1.459032e+06
# 116                   1.857095e+06
#
# [5 rows x 67 columns]

# %%
file_path = "/home/marijatochadse/3_output/EPOC/lh.thickness.txt"
df_lh_thick = create_MRI_csv(file_path, pat_labels_epoc)
df_lh_thick.head()
# Out:
# (90, 109)
#     lh.BN_Atlas.thickness  lh_A8m_L_thickness  lh_A8dl_L_thickness  \
# 111           epoc_p_1004               2.963                2.854
# 112           epoc_p_1005               3.314                3.170
# 113           epoc_p_1006               2.871                2.527
# 114           epoc_p_1008               3.125                2.735
# 116           epoc_p_1012               3.163                2.938
#
#      lh_A9l_L_thickness  lh_A6dl_L_thickness  lh_A6m_L_thickness  \
# 111               3.252                2.904               2.907
# 112               3.442                3.251               3.069
# 113               2.962                2.679               2.568
# 114               2.806                2.950               2.693
# 116               2.773                3.142               3.042
#
#      lh_A9m_L_thickness  lh_A10m_L_thickness  lh_46d_L_thickness  \
# 111               3.198                3.005               2.494
# 112               3.362                2.952               2.765
# 113               2.637                2.664               2.322
# 114               2.689                2.692               2.572
# 116               3.246                2.746               2.635
#
#      lh_IFJ_L_thickness  ...  lh_vmPOS_L_thickness  lh_mOccG_L_thickness  \
# 111               2.749  ...                 1.796                 2.256
# 112               2.819  ...                 1.984                 2.515
# 113               2.599  ...                 1.867                 2.086
# 114               2.584  ...                 2.029                 2.296
# 116               2.637  ...                 2.034                 2.177
#
#      lh_MT+_L_thickness  lh_OPC_L_thickness  lh_iOccG_L_thickness  \
# 111               2.480               1.996                 2.177
# 112               2.935               2.268                 2.193
# 113               2.389               2.067                 2.239
# 114               2.409               1.786                 2.121
# 116               2.367               1.745                 2.185
#
#      lh_msOccG_L_thickness  lh_lsOccG_L_thickness  lh_MeanThickness_thickness  \
# 111                  2.296                  2.384                     2.61708
# 112                  2.236                  2.523                     2.83068
# 113                  1.961                  2.188                     2.44460
# 114                  2.216                  2.420                     2.53168
# 116                  2.069                  2.303                     2.59052
#
#      BrainSegVolNotVent          eTIV
# 111           1136482.0  1.564502e+06
# 112           1118617.0  1.334034e+06
# 113           1003944.0  1.152532e+06
# 114           1130877.0  1.459032e+06
# 116           1359211.0  1.857095e+06
#
# [5 rows x 109 columns]

# %%
file_path = "/home/marijatochadse/3_output/EPOC/rh.thickness.txt"
df_rh_thick = create_MRI_csv(file_path, pat_labels_epoc)
df_rh_thick.head()
# Out:
# (90, 109)
#     rh.BN_Atlas.thickness  rh_A8m_R_thickness  rh_A8dl_R_thickness  \
# 111           epoc_p_1004               2.945                2.617
# 112           epoc_p_1005               3.130                2.897
# 113           epoc_p_1006               2.660                2.574
# 114           epoc_p_1008               2.996                2.563
# 116           epoc_p_1012               3.010                2.483
#
#      rh_A9l_R_thickness  rh_A6dl_R_thickness  rh_A6m_R_thickness  \
# 111               2.751                2.876               2.764
# 112               3.145                3.322               3.009
# 113               2.990                2.541               2.525
# 114               2.651                2.876               2.942
# 116               2.702                3.174               2.987
#
#      rh_A9m_R_thickness  rh_A10m_R_thickness  rh_46d_R_thickness  \
# 111               2.827                2.586               2.524
# 112               3.286                2.788               2.682
# 113               2.682                2.612               2.311
# 114               2.876                2.520               2.341
# 116               2.971                2.431               2.470
#
#      rh_IFJ_R_thickness  ...  rh_vmPOS_R_thickness  rh_mOccG_R_thickness  \
# 111               2.530  ...                 1.788                 2.285
# 112               2.729  ...                 1.827                 2.311
# 113               2.427  ...                 1.878                 2.093
# 114               2.363  ...                 1.912                 2.389
# 116               2.594  ...                 2.017                 2.208
#
#      rh_MT+_R_thickness  rh_OPC_R_thickness  rh_iOccG_R_thickness  \
# 111               2.476               1.961                 2.517
# 112               2.912               2.108                 2.615
# 113               2.682               1.992                 2.279
# 114               2.600               1.831                 2.238
# 116               2.602               1.910                 2.393
#
#      rh_msOccG_R_thickness  rh_lsOccG_R_thickness  rh_MeanThickness_thickness  \
# 111                  2.167                  2.326                     2.52861
# 112                  2.243                  2.395                     2.79726
# 113                  1.943                  2.199                     2.43814
# 114                  2.366                  2.408                     2.51816
# 116                  2.235                  2.331                     2.55943
#
#      BrainSegVolNotVent          eTIV
# 111           1136482.0  1.564502e+06
# 112           1118617.0  1.334034e+06
# 113           1003944.0  1.152532e+06
# 114           1130877.0  1.459032e+06
# 116           1359211.0  1.857095e+06
#
# [5 rows x 109 columns]

# %%
file_path = "/home/marijatochadse/3_output/EPOC/lh.volume.txt"
df_lh_vol = create_MRI_csv(file_path, pat_labels_epoc)
df_lh_vol.head()
# Out:
# (90, 108)
#     lh.BN_Atlas.volume  lh_A8m_L_volume  lh_A8dl_L_volume  lh_A9l_L_volume  \
# 111        epoc_p_1004           2548.0            3276.0           3634.0
# 112        epoc_p_1005           2590.0            3060.0           3970.0
# 113        epoc_p_1006           2007.0            2306.0           2949.0
# 114        epoc_p_1008           3017.0            3517.0           3890.0
# 116        epoc_p_1012           3266.0            4216.0           4445.0
#
#      lh_A6dl_L_volume  lh_A6m_L_volume  lh_A9m_L_volume  lh_A10m_L_volume  \
# 111            2682.0           2675.0           2975.0            4663.0
# 112            2290.0           2661.0           2678.0            3693.0
# 113            2448.0           2114.0           2335.0            3445.0
# 114            3935.0           2606.0           3206.0            4887.0
# 116            3743.0           4052.0           3669.0            4932.0
#
#      lh_46d_L_volume  lh_IFJ_L_volume  ...  lh_rLinG_L_volume  \
# 111           3910.0           4241.0  ...             2804.0
# 112           4313.0           3306.0  ...             1627.0
# 113           2969.0           2627.0  ...             2904.0
# 114           5145.0           2585.0  ...             2048.0
# 116           7208.0           3725.0  ...             3793.0
#
#      lh_vmPOS_L_volume  lh_mOccG_L_volume  lh_MT+_L_volume  lh_OPC_L_volume  \
# 111             3202.0             3043.0           3417.0           2894.0
# 112             2312.0             1720.0           2496.0           2275.0
# 113             3628.0             1686.0           1693.0           2629.0
# 114             2704.0             2684.0           2618.0           2975.0
# 116             3240.0             3090.0           3621.0           2478.0
#
#      lh_iOccG_L_volume  lh_msOccG_L_volume  lh_lsOccG_L_volume  \
# 111             3035.0              1597.0              2458.0
# 112             2341.0              1899.0              2124.0
# 113             2549.0              2011.0              2317.0
# 114             3029.0              2378.0              2832.0
# 116             3961.0              2138.0              3027.0
#
#      BrainSegVolNotVent          eTIV
# 111           1136482.0  1.564502e+06
# 112           1118617.0  1.334034e+06
# 113           1003944.0  1.152532e+06
# 114           1130877.0  1.459032e+06
# 116           1359211.0  1.857095e+06
#
# [5 rows x 108 columns]

# %%
file_path = "/home/marijatochadse/3_output/EPOC/rh.volume.txt"
df_rh_vol = create_MRI_csv(file_path, pat_labels_epoc)
df_rh_vol.head()
# Out:
# (90, 108)
#     rh.BN_Atlas.volume  rh_A8m_R_volume  rh_A8dl_R_volume  rh_A9l_R_volume  \
# 111        epoc_p_1004           3382.0            2881.0           4097.0
# 112        epoc_p_1005           2574.0            2250.0           3463.0
# 113        epoc_p_1006           2087.0            1924.0           3191.0
# 114        epoc_p_1008           3287.0            2491.0           3901.0
# 116        epoc_p_1012           3363.0            2684.0           4337.0
#
#      rh_A6dl_R_volume  rh_A6m_R_volume  rh_A9m_R_volume  rh_A10m_R_volume  \
# 111            3259.0           2468.0           3893.0            3905.0
# 112            2342.0           2241.0           3561.0            3464.0
# 113            1594.0           1926.0           2891.0            3242.0
# 114            2582.0           3367.0           3568.0            3689.0
# 116            3779.0           4097.0           4014.0            4248.0
#
#      rh_46d_R_volume  rh_IFJ_R_volume  ...  rh_rLinG_R_volume  \
# 111           4807.0           2551.0  ...             3225.0
# 112           4002.0           2060.0  ...             1742.0
# 113           3134.0           1712.0  ...             3199.0
# 114           3882.0           1978.0  ...             2353.0
# 116           5452.0           2927.0  ...             3058.0
#
#      rh_vmPOS_R_volume  rh_mOccG_R_volume  rh_MT+_R_volume  rh_OPC_R_volume  \
# 111             3149.0             2817.0           2629.0           2824.0
# 112             2070.0             2445.0           2969.0           2469.0
# 113             3305.0             2081.0           2464.0           2813.0
# 114             2572.0             2163.0           2784.0           2543.0
# 116             2807.0             3360.0           3732.0           2984.0
#
#      rh_iOccG_R_volume  rh_msOccG_R_volume  rh_lsOccG_R_volume  \
# 111             2962.0              2190.0              2715.0
# 112             3052.0              1846.0              2053.0
# 113             2680.0              2110.0              2593.0
# 114             2820.0              2629.0              3359.0
# 116             3913.0              2136.0              2489.0
#
#      BrainSegVolNotVent          eTIV
# 111           1136482.0  1.564502e+06
# 112           1118617.0  1.334034e+06
# 113           1003944.0  1.152532e+06
# 114           1130877.0  1.459032e+06
# 116           1359211.0  1.857095e+06
#
# [5 rows x 108 columns]

# %%
df_FS_all = pd.concat([df_aseg, df_lh_thick.iloc[:, 1:], df_rh_thick.iloc[:, 1:], df_lh_vol.iloc[:, 1:], df_rh_vol.iloc[:, 1:]], axis=1)

# %%
df_FS_all.shape
# Out:
# (90, 497)

# %%
df_FS_all.rename(columns={"Measure:volume": "subject"},inplace = True)

# %%
df_FS_all
# Out:
#          subject  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 111  epoc_p_1004                  5686.7              288.9
# 112  epoc_p_1005                  4581.4              157.1
# 113  epoc_p_1006                  7058.9              231.8
# 114  epoc_p_1008                  9492.9              160.9
# 116  epoc_p_1012                 10666.4              787.6
# ..           ...                     ...                ...
# 209  epoc_p_1136                 18804.4              629.4
# 210  epoc_p_1137                  7861.0              603.1
# 211  epoc_p_1139                  7507.0              306.0
# 212  epoc_p_1140                  6551.0              294.2
# 213  epoc_p_1141                  9904.6              305.4
#
#      Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  \
# 111                       12690.1                 58991.6
# 112                       14484.8                 53596.0
# 113                       14910.9                 55451.5
# 114                       31255.6                 43988.5
# 116                       18939.8                 73133.4
# ..                            ...                     ...
# 209                       11161.5                 48841.1
# 210                       16271.9                 67359.1
# 211                       12980.4                 56401.2
# 212                       11161.5                 52792.9
# 213                       15266.8                 67398.6
#
#      Left-Thalamus-Proper  Left-Caudate  Left-Putamen  Left-Pallidum  \
# 111                8284.0        3207.3        4425.4         1786.4
# 112                7802.4        3101.7        4596.6         1763.1
# 113                7464.9        3459.2        4485.9         1884.8
# 114                7728.0        3375.6        5109.4         2127.1
# 116                9412.4        3716.4        4606.5         2446.6
# ..                    ...           ...           ...            ...
# 209                5674.6        2718.5        3611.4         1578.3
# 210                8019.2        3897.1        5137.7         2292.7
# 211                6793.5        3416.8        4121.9         2081.4
# 212                7669.8        3917.8        5183.4         2291.9
# 213                9982.6        3920.2        5319.3         2630.2
#
#      3rd-Ventricle  ...  rh_rLinG_R_volume  rh_vmPOS_R_volume  \
# 111          972.2  ...             3225.0             3149.0
# 112          718.5  ...             1742.0             2070.0
# 113         1085.3  ...             3199.0             3305.0
# 114         1034.3  ...             2353.0             2572.0
# 116         1805.0  ...             3058.0             2807.0
# ..             ...  ...                ...                ...
# 209         1749.7  ...             2388.0             2370.0
# 210         1023.9  ...             3115.0             3783.0
# 211          895.1  ...             2254.0             2555.0
# 212          797.8  ...             3703.0             3610.0
# 213          984.5  ...             3876.0             3264.0
#
#      rh_mOccG_R_volume  rh_MT+_R_volume  rh_OPC_R_volume  rh_iOccG_R_volume  \
# 111             2817.0           2629.0           2824.0             2962.0
# 112             2445.0           2969.0           2469.0             3052.0
# 113             2081.0           2464.0           2813.0             2680.0
# 114             2163.0           2784.0           2543.0             2820.0
# 116             3360.0           3732.0           2984.0             3913.0
# ..                 ...              ...              ...                ...
# 209             1997.0           2011.0           1827.0             2327.0
# 210             2852.0           2962.0           3719.0             3476.0
# 211             2626.0           3058.0           2483.0             2746.0
# 212             2269.0           3937.0           3071.0             2970.0
# 213             2624.0           3410.0           3097.0             3215.0
#
#      rh_msOccG_R_volume  rh_lsOccG_R_volume  BrainSegVolNotVent          eTIV
# 111              2190.0              2715.0           1136482.0  1.564502e+06
# 112              1846.0              2053.0           1118617.0  1.334034e+06
# 113              2110.0              2593.0           1003944.0  1.152532e+06
# 114              2629.0              3359.0           1130877.0  1.459032e+06
# 116              2136.0              2489.0           1359211.0  1.857095e+06
# ..                  ...                 ...                 ...           ...
# 209              1432.0              1790.0            942936.0  1.445503e+06
# 210              1953.0              1951.0           1198165.0  1.379477e+06
# 211              1707.0              2043.0           1046200.0  1.294923e+06
# 212              2645.0              2680.0           1209174.0  1.570591e+06
# 213              2382.0              2886.0           1375080.0  1.842163e+06
#
# [90 rows x 497 columns]

# %%
df_FS_all.to_csv('/home/marijatochadse/1_data/EPOC/csv_files/MRI_csv_files/FS_all_dem_pat.csv', index=False)
