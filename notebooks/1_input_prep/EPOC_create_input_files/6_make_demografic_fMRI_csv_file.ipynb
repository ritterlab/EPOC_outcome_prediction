# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pyreadstat
import seaborn as sns
from scipy import stats
import os
import shutil
import glob

cmap = plt.cm.rainbow

# %%
fMRI_data = pd.read_csv('/home/marijatochadse/1_data/EPOC/csv_files/MRI_csv_files/rsfMRI_80pat.csv')

# %%
fMRI_data.head()
# Out:
#        subject         0         1         2         3         4         5  \
# 0  epoc_p_1004  0.455885  0.416174  0.108076  0.356433  0.279444  0.305667
# 1  epoc_p_1005  0.884573  0.775685  0.731658  0.515574  0.475172  0.606112
# 2  epoc_p_1006  0.579738  0.796199  0.389679  0.724294  0.580416  0.721528
# 3  epoc_p_1008  0.782747  0.542955  0.285548  0.106172  0.309814  0.634742
# 4  epoc_p_1012  0.807958  0.125688  0.284293  0.369072  0.223351  0.596993
#
#           6         7         8  ...     30618     30619     30620     30621  \
# 0  0.195758  0.226338  0.249908  ...  0.719358  0.542248  0.495881  0.520116
# 1  0.736526  0.563819  0.558976  ...  0.699611  0.642350  0.459945  0.413568
# 2  0.365477  0.485122  0.364495  ...  0.699869  0.564032  0.784806  0.638208
# 3  0.745536  0.288720  0.322136  ...  0.669404  0.701875  0.542652  0.539693
# 4  0.582179  0.485796  0.453636  ...  0.752685  0.684370  0.661540  0.670104
#
# ...

# %%
fMRI_data.shape
# Out:
# (80, 30629)

# %%
# get demografic info
epoc_dem = pd.read_csv('/home/marijatochadse/1_data/EPOC/csv_files/EPOC_fMRI_pat_80.csv', sep=",")

# %%
epoc_dem = epoc_dem.sort_values(by = 'Code')
epoc_dem.index = np.arange(epoc_dem.shape[0])
epoc_dem
# Out:
#            Code        Code2  Familiencode              Relation Status  \
# 0   epoc_p_1004  EPOC_P_1004        3013.0  Index ohne Verwandte  Index
# 1   epoc_p_1005  EPOC_P_1005        3014.0  Index ohne Verwandte  Index
# 2   epoc_p_1006  EPOC_P_1006        3018.0  Index ohne Verwandte  Index
# 3   epoc_p_1008  EPOC_P_1008        3022.0  Index ohne Verwandte  Index
# 4   epoc_p_1012  EPOC_P_1012        3028.0  Index ohne Verwandte  Index
# ..          ...          ...           ...                   ...    ...
# 75  epoc_p_1132  EPOC_P_1132        3261.0  Index mit Verwandten  Index
# 76  epoc_p_1137  EPOC_P_1137        3266.0  Index ohne Verwandte  Index
# 77  epoc_p_1139  EPOC_P_1139        3269.0  Index ohne Verwandte  Index
# 78  epoc_p_1140  EPOC_P_1140        3270.0  Index ohne Verwandte  Index
# 79  epoc_p_1141  EPOC_P_1141        3272.0  Index mit Verwandten  Index
#
#     StatusOCD_binary  Center Gruppe_Neu  Sample_verlaufBerlin  \
# ...

# %%
df_dem_fMRI = pd.concat([epoc_dem, fMRI_data.iloc[:,1:]], axis=1)

# %%
df_dem_fMRI.head()
# Out:
#           Code        Code2  Familiencode              Relation Status  \
# 0  epoc_p_1004  EPOC_P_1004        3013.0  Index ohne Verwandte  Index
# 1  epoc_p_1005  EPOC_P_1005        3014.0  Index ohne Verwandte  Index
# 2  epoc_p_1006  EPOC_P_1006        3018.0  Index ohne Verwandte  Index
# 3  epoc_p_1008  EPOC_P_1008        3022.0  Index ohne Verwandte  Index
# 4  epoc_p_1012  EPOC_P_1012        3028.0  Index ohne Verwandte  Index
#
#    StatusOCD_binary  Center Gruppe_Neu  Sample_verlaufBerlin  \
# 0               1.0  Berlin    OCD_Med                   1.0
# 1               1.0  Berlin  OCD_NoMed                   1.0
# 2               1.0  Berlin  OCD_NoMed                   1.0
# 3               1.0  Berlin  OCD_NoMed                   1.0
# 4               1.0  Berlin  OCD_NoMed                   1.0
#
#             Finish_vsQuit  ...     30618     30619     30620     30621  \
# 0  reguläres Therapieende  ...  0.719358  0.542248  0.495881  0.520116
# ...

# %%
df_dem_fMRI.to_csv('/home/marijatochadse/1_data/EPOC/csv_files/EPOC_TAB_fMRI_pat_80.csv', index=False)
