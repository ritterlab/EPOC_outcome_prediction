# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from glob import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.lines import Line2D
import seaborn as sns

sys.path.insert(0, "../")
#from helper.plotGraphs import *
from helper.plotResults import plot_result, plot_training_curves

sns.set(style="whitegrid", context='paper', color_codes=False)

# %% [markdown]
# ### Response prediction by age and sex

# %%
df_0 = pd.read_csv('/home/marijatochadse/2_scripts/EPOC_MLpipeline/results/classification_min/EPOC_T1_age_sex/20230525-0958/run.csv')

# %%
fig = plot_result(df_0, hue="technique", legend=True)
plt.show()

# %%
fig = plot_result(df_0, x="train_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df_0, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %% [markdown]
# ### Response prediction by structural MRI (age or sex confounds)

# %%
df_1 = pd.read_csv('/home/marijatochadse/2_scripts/EPOC_MLpipeline/results/classification/EPOC_T1_MRI_conf_age_sex/20230525-0935/run.csv')

# %%
fig = plot_result(df_1, hue="technique", legend=True)
plt.show()

# %%
fig = plot_result(df_1, x="train_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df_1, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()
