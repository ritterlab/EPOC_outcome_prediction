# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from glob import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.lines import Line2D
import seaborn as sns

sys.path.insert(0, "../")
#from helper.plotGraphs import *
from helper.plotResults import plot_result, plot_training_curves

sns.set(style="whitegrid", context='paper', color_codes=False)

# %% [markdown]
# ### Response prediction by age and sex

# %%
df_0 = pd.read_csv('/home/marijatochadse/2_scripts/MLpipeline_split/results/classification_template/debug_run/20230526-1427/run.csv')

# %%
fig = plot_result(df_0, x="train_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df_0, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %% [markdown]
# ### Response prediction by structural MRI (age or sex confounds)

# %%
file_path1 = "/home/marijatochadse/2_scripts/MLpipeline_split/results/classification_template/EPOC_T1_MRI_conf_age_sex/20230606-1122/run.csv"
file_path2 = "/home/marijatochadse/2_scripts/MLpipeline_split/results/classification_template_2/EPOC_T1_MRI_conf_age_sex/20230606-1154/run.csv"
file_path3 = "/home/marijatochadse/2_scripts/MLpipeline_split/results/classification_template_3/EPOC_T1_MRI_conf_age_sex/20230606-1217/run.csv"
file_path4 = "/home/marijatochadse/2_scripts/MLpipeline_split/results/classification_template_4/EPOC_T1_MRI_conf_age_sex/20230606-1245/run.csv"
file_path5 = "/home/marijatochadse/2_scripts/MLpipeline_split/results/classification_template_5/EPOC_T1_MRI_conf_age_sex/20230606-1255/run.csv"
file_path6 = "/home/marijatochadse/2_scripts/MLpipeline_split/results/classification_template_6/EPOC_T1_MRI_conf_age_sex/20230606-1259/run.csv"
file_path7 = "/home/marijatochadse/2_scripts/MLpipeline_split/results/classification_template_7/EPOC_T1_MRI_conf_age_sex/20230606-1302/run.csv"
file_path8 = "/home/marijatochadse/2_scripts/MLpipeline_split/results/classification_template_8/EPOC_T1_MRI_conf_age_sex/20230606-1307/run.csv"
file_path9 = "/home/marijatochadse/2_scripts/MLpipeline_split/results/classification_template_9/EPOC_T1_MRI_conf_age_sex/20230606-1311/run.csv"
file_path10 = "/home/marijatochadse/2_scripts/MLpipeline_split/results/classification_template_10/EPOC_T1_MRI_conf_age_sex/20230606-1314/run.csv"

# %%
df1 = pd.read_csv(file_path1, sep=",")
df2 = pd.read_csv(file_path2, sep=",")
df3 = pd.read_csv(file_path3, sep=",")
df4 = pd.read_csv(file_path4, sep=",")
df5 = pd.read_csv(file_path5, sep=",")
df6 = pd.read_csv(file_path6, sep=",")
df7 = pd.read_csv(file_path7, sep=",")
df8 = pd.read_csv(file_path8, sep=",")
df9 = pd.read_csv(file_path9, sep=",")
df10 = pd.read_csv(file_path10, sep=",")

# %%
fig = plot_result(df1, hue="technique", legend=True)
plt.show()

# %%
fig = plot_result(df1, x="train_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df1, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df2, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df3, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df4, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df5, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df6, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df7, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df8, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df9, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()

# %%
fig = plot_result(df10, x="val_metric", groupby="technique", hue="model", legend=True)
plt.show()
