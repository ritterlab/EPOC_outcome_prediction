# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pyreadstat
import seaborn as sns
from scipy import stats

cmap = plt.cm.rainbow
import h5py

# %%
df = pd.read_csv("/home/marijatochadse/3_output/EPOC/aseg_stats.txt", sep="\t")

# %%
df.head()
# Out:
#              Measure:volume  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0  sub-epocc1001/freesurfer                  2709.6               88.5
# 1  sub-epocc1002/freesurfer                  3906.3              398.1
# 2  sub-epocc1005/freesurfer                 11095.6              209.1
# 3  sub-epocc1006/freesurfer                 19766.5              592.9
# 4  sub-epocc1008/freesurfer                  4777.8              128.2
#
#    Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus-Proper  \
# 0                       19233.2                 59115.6                8507.4
# 1                       14661.6                 49518.8                7960.9
# 2                       15291.0                 56806.8                8034.3
# 3                       15920.5                 63913.0                9019.9
# 4                       13427.4                 52045.5                7569.0
#
#    Left-Caudate  Left-Putamen  Left-Pallidum  3rd-Ventricle  ...  \
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Measure:volume', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus-Proper', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus-Proper', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', '5th-Ventricle', 'WM-hypointensities', 'Left-WM-hypointensities', 'Right-WM-hypointensities', 'non-WM-hypointensities', 'Left-non-WM-hypointensities', 'Right-non-WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'BrainSegVol', 'BrainSegVolNotVent', 'B
# ...

# %%
df_lh_thick = pd.read_csv("/home/marijatochadse/3_output/EPOC/lh.thickness.txt", sep="\t")

# %%
df_lh_thick.head()
# Out:
#       lh.BN_Atlas.thickness  lh_A8m_L_thickness  lh_A8dl_L_thickness  \
# 0  sub-epocc1001/freesurfer               2.931                2.809
# 1  sub-epocc1002/freesurfer               3.008                2.846
# 2  sub-epocc1005/freesurfer               2.948                2.730
# 3  sub-epocc1006/freesurfer               3.163                2.790
# 4  sub-epocc1008/freesurfer               2.777                2.787
#
#    lh_A9l_L_thickness  lh_A6dl_L_thickness  lh_A6m_L_thickness  \
# 0               2.878                2.678               2.884
# 1               2.939                2.902               2.761
# 2               2.912                2.945               3.033
# 3               2.973                2.824               3.123
# 4               2.951                2.887               2.883
#
#    lh_A9m_L_thickness  lh_A10m_L_thickness  lh_46d_L_thickness  \
# 0               3.127                2.995               2.596
# ...

# %%
print(df_lh_thick.columns.tolist())
# Out:
# ['lh.BN_Atlas.thickness', 'lh_A8m_L_thickness', 'lh_A8dl_L_thickness', 'lh_A9l_L_thickness', 'lh_A6dl_L_thickness', 'lh_A6m_L_thickness', 'lh_A9m_L_thickness', 'lh_A10m_L_thickness', 'lh_46d_L_thickness', 'lh_IFJ_L_thickness', 'lh_A46_L_thickness', 'lh_46v_L_thickness', 'lh_A8vl_L_thickness', 'lh_A6vl_L_thickness', 'lh_A10l_L_thickness', 'lh_A44d_L_thickness', 'lh_IFS_L_thickness', 'lh_A45c_L_thickness', 'lh_A45r_L_thickness', 'lh_A44op_L_thickness', 'lh_A44v_L_thickness', 'lh_A14m_L_thickness', 'lh_47o_L_thickness', 'lh_A11l_L_thickness', 'lh_A11m_L_thickness', 'lh_A13_L_thickness', 'lh_47l_L_thickness', 'lh_A4hf_L_thickness', 'lh_A6cdl_L_thickness', 'lh_A4ul_L_thickness', 'lh_A4t_L_thickness', 'lh_A4tl_L_thickness', 'lh_A6cvl_L_thickness', 'lh_3ll_L_thickness', 'lh_A4ll_L_thickness', 'lh_A38m_L_thickness', 'lh_42_L_thickness', 'lh_TE1.2_L_thickness', 'lh_A22c_L_thickness', 'lh_A38l_L_thickness', 'lh_A22r_L_thickness', 'lh_A21c_L_thickness', 'lh_A21r_L_thickness', 'lh_A37dl_L_thickn
# ...

# %%
df_lh_vol = pd.read_csv("/home/marijatochadse/3_output/EPOC/lh.volume.txt", sep="\t")

# %%
df_lh_vol.head()
# Out:
#          lh.BN_Atlas.volume  lh_A8m_L_volume  lh_A8dl_L_volume  \
# 0  sub-epocc1001/freesurfer           2539.0            3796.0
# 1  sub-epocc1002/freesurfer           2471.0            3795.0
# 2  sub-epocc1005/freesurfer           3944.0            6070.0
# 3  sub-epocc1006/freesurfer           3037.0            3974.0
# 4  sub-epocc1008/freesurfer           2391.0            3818.0
#
#    lh_A9l_L_volume  lh_A6dl_L_volume  lh_A6m_L_volume  lh_A9m_L_volume  \
# 0           3348.0            2183.0           2307.0           2526.0
# 1           3339.0            2642.0           2858.0           2653.0
# 2           4976.0            3282.0           3138.0           3563.0
# 3           4907.0            2954.0           3173.0           3039.0
# 4           3403.0            2447.0           2443.0           2743.0
#
#    lh_A10m_L_volume  lh_46d_L_volume  lh_IFJ_L_volume  ...  lh_rLinG_L_volume  \
# ...

# %%
print(df_lh_vol.columns.tolist())
# Out:
# ['lh.BN_Atlas.volume', 'lh_A8m_L_volume', 'lh_A8dl_L_volume', 'lh_A9l_L_volume', 'lh_A6dl_L_volume', 'lh_A6m_L_volume', 'lh_A9m_L_volume', 'lh_A10m_L_volume', 'lh_46d_L_volume', 'lh_IFJ_L_volume', 'lh_A46_L_volume', 'lh_46v_L_volume', 'lh_A8vl_L_volume', 'lh_A6vl_L_volume', 'lh_A10l_L_volume', 'lh_A44d_L_volume', 'lh_IFS_L_volume', 'lh_A45c_L_volume', 'lh_A45r_L_volume', 'lh_A44op_L_volume', 'lh_A44v_L_volume', 'lh_A14m_L_volume', 'lh_47o_L_volume', 'lh_A11l_L_volume', 'lh_A11m_L_volume', 'lh_A13_L_volume', 'lh_47l_L_volume', 'lh_A4hf_L_volume', 'lh_A6cdl_L_volume', 'lh_A4ul_L_volume', 'lh_A4t_L_volume', 'lh_A4tl_L_volume', 'lh_A6cvl_L_volume', 'lh_3ll_L_volume', 'lh_A4ll_L_volume', 'lh_A38m_L_volume', 'lh_42_L_volume', 'lh_TE1.2_L_volume', 'lh_A22c_L_volume', 'lh_A38l_L_volume', 'lh_A22r_L_volume', 'lh_A21c_L_volume', 'lh_A21r_L_volume', 'lh_A37dl_L_volume', 'lh_aSTS_L_volume', 'lh_A20iv_L_volume', 'lh_A37elv_L_volume', 'lh_A20r_L_volume', 'lh_A20il_L_volume', 'lh_A37vl_L_volume', '
# ...
