# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import shutil
from glob import glob
# Out:
# /home/marijatochadse/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/marijatochadse/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
SAVE_DIR = '/home/marijatochadse/1_data/EPOC/EPOC_graphs/'

# %%
df = pd.concat([pd.read_csv(csv) for csv in glob(SAVE_DIR+"/*_rs_graph_features.csv")], ignore_index=True)

# %%
df
# Out:
#     weighted_transitivity  weighted_global_efficiency  \
# 0                0.236575                    1.647731
# 1                0.255138                    1.778102
# 2                0.486916                    2.445213
# 3                0.210807                    1.488729
# 4                0.231879                    1.581786
# ..                    ...                         ...
# 88               0.303957                    1.927533
# 89               0.240190                    1.622751
# 90               0.246063                    1.641877
# 91               0.450053                    2.652274
# 92               0.192709                    1.460678
#
#     weighted_clustering_coefficient_zhang  weighted_clustering_coefficient  \
# 0                                0.330774                         0.236575
# 1                                0.361201                         0.255138
# 2                                0.535956                         0.486916
# 3                                0.298204                         0.210807
# 4                                0.325951                         0.231879
# ..                                    ...                              ...
# 88                               0.403521                         0.303957
# 89                               0.338560                         0.240190
# 90                               0.337415                         0.246063
# 91                               0.545494                         0.450053
# 92                               0.275746                         0.192709
#
#     weighted_triangle_number  weighted_density  weighted_sw_sigma  \
# 0                7965.488261          0.283539           0.797261
# 1                8656.828255          0.303526           0.743765
# 2               16521.072410          0.506146           0.806270
# 3                7152.667090          0.253617           0.959284
# 4                7807.375703          0.277847           0.888968
# ..                       ...               ...                ...
# 88              10313.261849          0.349962           0.753487
# 89               8149.655913          0.286528           0.865892
# 90               8284.935541          0.292217           0.852548
# 91              15270.296831          0.481544           0.631231
# 92               6438.612050          0.236736           0.932194
#
#     weighted_sw_omega  weighted_sw_omega_2     subject_ID
# 0            0.640797            -2.849234  sub-epocp1024
# 1            0.579046            -3.573158  sub-epocp1079
# 2            0.732596            -5.860778  sub-epocp1141
# 3            0.769167            -1.036699  sub-epocp1004
# 4            0.710438            -1.832623  sub-epocp1029
# ..                ...                  ...            ...
# 88           0.609865            -3.756430  sub-epocp1072
# 89           0.681694            -2.166765  sub-epocp1050
# 90           0.697325            -1.663826  sub-epocp1009
# 91           0.516151           -13.574408  sub-epocp1031
# 92           0.771854            -0.781172  sub-epocp1110
#
# [93 rows x 10 columns]

# %%
df_subs = df.copy()

for isub in range(df.shape[0]):
    df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# Out:
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]
# /tmp/ipykernel_252452/3863884497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subs['subject_ID'][isub] = df['subject_ID'][isub][4:8] + '_' + df['subject_ID'][isub][8] + '_' + df['subject_ID'][isub][9:None]

# %%
df_subs
# Out:
#     weighted_transitivity  weighted_global_efficiency  \
# 0                0.236575                    1.647731
# 1                0.255138                    1.778102
# 2                0.486916                    2.445213
# 3                0.210807                    1.488729
# 4                0.231879                    1.581786
# ..                    ...                         ...
# 88               0.303957                    1.927533
# 89               0.240190                    1.622751
# 90               0.246063                    1.641877
# 91               0.450053                    2.652274
# 92               0.192709                    1.460678
#
#     weighted_clustering_coefficient_zhang  weighted_clustering_coefficient  \
# 0                                0.330774                         0.236575
# 1                                0.361201                         0.255138
# 2                                0.535956                         0.486916
# 3                                0.298204                         0.210807
# 4                                0.325951                         0.231879
# ..                                    ...                              ...
# 88                               0.403521                         0.303957
# 89                               0.338560                         0.240190
# 90                               0.337415                         0.246063
# 91                               0.545494                         0.450053
# 92                               0.275746                         0.192709
#
#     weighted_triangle_number  weighted_density  weighted_sw_sigma  \
# 0                7965.488261          0.283539           0.797261
# 1                8656.828255          0.303526           0.743765
# 2               16521.072410          0.506146           0.806270
# 3                7152.667090          0.253617           0.959284
# 4                7807.375703          0.277847           0.888968
# ..                       ...               ...                ...
# 88              10313.261849          0.349962           0.753487
# 89               8149.655913          0.286528           0.865892
# 90               8284.935541          0.292217           0.852548
# 91              15270.296831          0.481544           0.631231
# 92               6438.612050          0.236736           0.932194
#
#     weighted_sw_omega  weighted_sw_omega_2   subject_ID
# 0            0.640797            -2.849234  epoc_p_1024
# 1            0.579046            -3.573158  epoc_p_1079
# 2            0.732596            -5.860778  epoc_p_1141
# 3            0.769167            -1.036699  epoc_p_1004
# 4            0.710438            -1.832623  epoc_p_1029
# ..                ...                  ...          ...
# 88           0.609865            -3.756430  epoc_p_1072
# 89           0.681694            -2.166765  epoc_p_1050
# 90           0.697325            -1.663826  epoc_p_1009
# 91           0.516151           -13.574408  epoc_p_1031
# 92           0.771854            -0.781172  epoc_p_1110
#
# [93 rows x 10 columns]

# %%
sorted_df = df_subs.sort_values(by='subject_ID').reset_index(drop=True)

# %%
sorted_df
# Out:
#     weighted_transitivity  weighted_global_efficiency  \
# 0                0.210807                    1.488729
# 1                0.358441                    2.109690
# 2                0.372082                    2.147524
# 3                0.310059                    1.877808
# 4                0.246063                    1.641877
# ..                    ...                         ...
# 88               0.286231                    1.856257
# 89               0.433144                    2.477696
# 90               0.203426                    1.499104
# 91               0.274150                    1.688831
# 92               0.486916                    2.445213
#
#     weighted_clustering_coefficient_zhang  weighted_clustering_coefficient  \
# 0                                0.298204                         0.210807
# 1                                0.450025                         0.358441
# 2                                0.471397                         0.372082
# 3                                0.399801                         0.310059
# 4                                0.337415                         0.246063
# ..                                    ...                              ...
# 88                               0.396685                         0.286231
# 89                               0.511428                         0.433144
# 90                               0.293107                         0.203426
# 91                               0.361709                         0.274150
# 92                               0.535956                         0.486916
#
#     weighted_triangle_number  weighted_density  weighted_sw_sigma  \
# 0                7152.667090          0.253617           0.959284
# 1               12068.700852          0.397892           0.711052
# 2               12624.729478          0.412119           0.763861
# 3               10520.289447          0.351353           0.758136
# 4                8284.935541          0.292217           0.852548
# ..                       ...               ...                ...
# 88               9711.801453          0.333441           0.768086
# 89              14471.760776          0.465089           0.700754
# 90               6902.248188          0.249445           0.929315
# 91               9301.912742          0.314068           0.865704
# 92              16521.072410          0.506146           0.806270
#
#     weighted_sw_omega  weighted_sw_omega_2   subject_ID
# 0            0.769167            -1.036699  epoc_p_1004
# 1            0.586217            -8.065349  epoc_p_1005
# 2            0.618031            -5.836713  epoc_p_1006
# 3            0.622579            -3.174793  epoc_p_1008
# 4            0.697325            -1.663826  epoc_p_1009
# ..                ...                  ...          ...
# 88           0.593285            -4.489995  epoc_p_1133
# 89           0.605408            -8.170456  epoc_p_1137
# 90           0.754477            -1.143925  epoc_p_1139
# 91           0.704096            -1.948796  epoc_p_1140
# 92           0.732596            -5.860778  epoc_p_1141
#
# [93 rows x 10 columns]

# %%
# select only subjects with demografic info
epoc_dem = pd.read_csv('/home/marijatochadse/1_data/EPOC/csv_files/EPOC_fMRI_pat_80.csv', sep=",")
pat_labels_epoc = epoc_dem['Code'].unique()
pat_labels_epoc.sort()
print(pat_labels_epoc.shape)
pat_labels_epoc = np.ndarray.tolist(pat_labels_epoc)
print(pat_labels_epoc)
# Out:
# (80,)
# ['epoc_p_1004', 'epoc_p_1005', 'epoc_p_1006', 'epoc_p_1008', 'epoc_p_1012', 'epoc_p_1013', 'epoc_p_1014', 'epoc_p_1015', 'epoc_p_1016', 'epoc_p_1017', 'epoc_p_1018', 'epoc_p_1019', 'epoc_p_1021', 'epoc_p_1022', 'epoc_p_1023', 'epoc_p_1024', 'epoc_p_1025', 'epoc_p_1027', 'epoc_p_1029', 'epoc_p_1030', 'epoc_p_1031', 'epoc_p_1033', 'epoc_p_1034', 'epoc_p_1035', 'epoc_p_1036', 'epoc_p_1037', 'epoc_p_1039', 'epoc_p_1040', 'epoc_p_1043', 'epoc_p_1044', 'epoc_p_1045', 'epoc_p_1047', 'epoc_p_1048', 'epoc_p_1050', 'epoc_p_1051', 'epoc_p_1052', 'epoc_p_1054', 'epoc_p_1057', 'epoc_p_1059', 'epoc_p_1061', 'epoc_p_1062', 'epoc_p_1063', 'epoc_p_1064', 'epoc_p_1065', 'epoc_p_1067', 'epoc_p_1069', 'epoc_p_1071', 'epoc_p_1072', 'epoc_p_1073', 'epoc_p_1074', 'epoc_p_1079', 'epoc_p_1080', 'epoc_p_1085', 'epoc_p_1086', 'epoc_p_1087', 'epoc_p_1089', 'epoc_p_1091', 'epoc_p_1093', 'epoc_p_1094', 'epoc_p_1097', 'epoc_p_1099', 'epoc_p_1100', 'epoc_p_1103', 'epoc_p_1108', 'epoc_p_1109', 'epoc_p_1110', 'epoc_p_1114', 'epoc_p_1116', 'epoc_p_1118', 'epoc_p_1119', 'epoc_p_1120', 'epoc_p_1123', 'epoc_p_1124', 'epoc_p_1129', 'epoc_p_1130', 'epoc_p_1132', 'epoc_p_1137', 'epoc_p_1139', 'epoc_p_1140', 'epoc_p_1141']

# %%
df_rs =sorted_df.loc[sorted_df.iloc[:,-1].isin(pat_labels_epoc)]
print(df_rs.shape)
# Out:
# (80, 10)

# %%
df_rs = df_rs.reset_index(drop=True)

# %%
df_rs
# Out:
#     weighted_transitivity  weighted_global_efficiency  \
# 0                0.210807                    1.488729
# 1                0.358441                    2.109690
# 2                0.372082                    2.147524
# 3                0.310059                    1.877808
# 4                0.324958                    1.879608
# ..                    ...                         ...
# 75               0.316983                    1.876920
# 76               0.433144                    2.477696
# 77               0.203426                    1.499104
# 78               0.274150                    1.688831
# 79               0.486916                    2.445213
#
#     weighted_clustering_coefficient_zhang  weighted_clustering_coefficient  \
# 0                                0.298204                         0.210807
# 1                                0.450025                         0.358441
# 2                                0.471397                         0.372082
# 3                                0.399801                         0.310059
# 4                                0.416050                         0.324958
# ..                                    ...                              ...
# 75                               0.403642                         0.316983
# 76                               0.511428                         0.433144
# 77                               0.293107                         0.203426
# 78                               0.361709                         0.274150
# 79                               0.535956                         0.486916
#
#     weighted_triangle_number  weighted_density  weighted_sw_sigma  \
# 0                7152.667090          0.253617           0.959284
# 1               12068.700852          0.397892           0.711052
# 2               12624.729478          0.412119           0.763861
# 3               10520.289447          0.351353           0.758136
# 4               11025.837838          0.364945           0.852402
# ..                       ...               ...                ...
# 75              10755.227459          0.359051           0.783973
# 76              14471.760776          0.465089           0.700754
# 77               6902.248188          0.249445           0.929315
# 78               9301.912742          0.314068           0.865704
# 79              16521.072410          0.506146           0.806270
#
#     weighted_sw_omega  weighted_sw_omega_2   subject_ID
# 0            0.769167            -1.036699  epoc_p_1004
# 1            0.586217            -8.065349  epoc_p_1005
# 2            0.618031            -5.836713  epoc_p_1006
# 3            0.622579            -3.174793  epoc_p_1008
# 4            0.694523            -2.959736  epoc_p_1012
# ..                ...                  ...          ...
# 75           0.656073            -2.832575  epoc_p_1132
# 76           0.605408            -8.170456  epoc_p_1137
# 77           0.754477            -1.143925  epoc_p_1139
# 78           0.704096            -1.948796  epoc_p_1140
# 79           0.732596            -5.860778  epoc_p_1141
#
# [80 rows x 10 columns]

# %%
df_rs.to_csv('/home/marijatochadse/1_data/EPOC/csv_files/MRI_csv_files/global_graph_rsfMRI_80pat.csv', index=False)
