# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pyreadstat
import seaborn as sns
from scipy import stats
import os
import shutil
import glob
# Out:
# /home/marijatochadse/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/marijatochadse/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 300)

# %%
fMRI_data = pd.read_csv('/home/marijatochadse/1_data/EPOC/csv_files/MRI_csv_files/global_graph_rsfMRI_80pat.csv')

# %%
fMRI_data.head()
# Out:
#    weighted_transitivity  weighted_global_efficiency  \
# 0               0.210807                    1.488729
# 1               0.358441                    2.109690
# 2               0.372082                    2.147524
# 3               0.310059                    1.877808
# 4               0.324958                    1.879608
#
#    weighted_clustering_coefficient_zhang  weighted_clustering_coefficient  \
# 0                               0.298204                         0.210807
# 1                               0.450025                         0.358441
# 2                               0.471397                         0.372082
# 3                               0.399801                         0.310059
# 4                               0.416050                         0.324958
#
#    weighted_triangle_number  weighted_density  weighted_sw_sigma  \
# 0               7152.667090          0.253617           0.959284
# 1              12068.700852          0.397892           0.711052
# ...

# %%
fMRI_data.shape
# Out:
# (80, 10)

# %%
# get demografic info
epoc_dem = pd.read_csv('/home/marijatochadse/1_data/EPOC/csv_files/EPOC_fMRI_pat_80.csv', sep=",")

# %%
epoc_dem = epoc_dem.sort_values(by = 'Code')
epoc_dem.index = np.arange(epoc_dem.shape[0])
epoc_dem
# Out:
#            Code        Code2  Familiencode              Relation Status  \
# 0   epoc_p_1004  EPOC_P_1004        3013.0  Index ohne Verwandte  Index
# 1   epoc_p_1005  EPOC_P_1005        3014.0  Index ohne Verwandte  Index
# 2   epoc_p_1006  EPOC_P_1006        3018.0  Index ohne Verwandte  Index
# 3   epoc_p_1008  EPOC_P_1008        3022.0  Index ohne Verwandte  Index
# 4   epoc_p_1012  EPOC_P_1012        3028.0  Index ohne Verwandte  Index
# ..          ...          ...           ...                   ...    ...
# 75  epoc_p_1132  EPOC_P_1132        3261.0  Index mit Verwandten  Index
# 76  epoc_p_1137  EPOC_P_1137        3266.0  Index ohne Verwandte  Index
# 77  epoc_p_1139  EPOC_P_1139        3269.0  Index ohne Verwandte  Index
# 78  epoc_p_1140  EPOC_P_1140        3270.0  Index ohne Verwandte  Index
# 79  epoc_p_1141  EPOC_P_1141        3272.0  Index mit Verwandten  Index
#
#     StatusOCD_binary  Center Gruppe_Neu  Sample_verlaufBerlin  \
# ...

# %%
df_dem_fMRI = pd.concat([epoc_dem, fMRI_data.iloc[:,0:-1]], axis=1)

# %%
df_dem_fMRI.head()
# Out:
#           Code        Code2  Familiencode              Relation Status  \
# 0  epoc_p_1004  EPOC_P_1004        3013.0  Index ohne Verwandte  Index
# 1  epoc_p_1005  EPOC_P_1005        3014.0  Index ohne Verwandte  Index
# 2  epoc_p_1006  EPOC_P_1006        3018.0  Index ohne Verwandte  Index
# 3  epoc_p_1008  EPOC_P_1008        3022.0  Index ohne Verwandte  Index
# 4  epoc_p_1012  EPOC_P_1012        3028.0  Index ohne Verwandte  Index
#
#    StatusOCD_binary  Center Gruppe_Neu  Sample_verlaufBerlin  \
# 0               1.0  Berlin    OCD_Med                   1.0
# 1               1.0  Berlin  OCD_NoMed                   1.0
# 2               1.0  Berlin  OCD_NoMed                   1.0
# 3               1.0  Berlin  OCD_NoMed                   1.0
# 4               1.0  Berlin  OCD_NoMed                   1.0
#
#             Finish_vsQuit  ...  Cz_400to1000_Av_neutr_environs_GC  \
# 0  reguläres Therapieende  ...                           0.004298
# ...

# %%
df_dem_fMRI['Code'] == fMRI_data['subject_ID']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45    True
# 46    True
# 47    True
# 48    True
# 49    True
# 50    True
# 51    True
# 52    True
# 53    True
# 54    True
# 55    True
# 56    True
# 57    True
# 58    True
# 59    True
# 60    True
# 61    True
# 62    True
# 63    True
# 64    True
# 65    True
# 66    True
# 67    True
# 68    True
# 69    True
# 70    True
# 71    True
# 72    True
# 73    True
# 74    True
# 75    True
# ...

# %%
df_dem_fMRI.to_csv('/home/marijatochadse/1_data/EPOC/csv_files/EPOC_TAB_graph_fMRI_pat_80.csv', index=False)
